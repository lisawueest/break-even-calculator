# %%
pip install requests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [requests]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

url = ""

resp = requests.post(
    url,
    json={
        "verkaufspreis": 50,
        "variable_kosten": 30,
        "fixkosten": 1000
    }
)

data = resp.json()
print(data)
